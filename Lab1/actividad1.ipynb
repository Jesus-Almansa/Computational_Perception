# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read an image from file
# image_path = 'C:\Users\JT\OneDrive - UNIR\UNIR\Primer Cuatrimestre\Percepcion Computacional\Actividades\Computational_Perception\Lab1\image1.png'
# image = cv2.imread(image_path)
image = cv2.imread("image1.png")

# Check if the image was successfully loaded
if image is None:
    print(f"Error: Unable to load the image from {image_path}")
else:
    # Display the image using OpenCV
    # cv2.imshow('Image', image)
    # cv2.waitKey(0)  # Wait until a key is pressed 
    # cv2.destroyAllWindows()

    # Alternatively, display the image using Matplotlib
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title('Image')
    plt.show()

# %%
def image_transformations(input_image, transformation_type, parameter):
    # Perform image transformations
    
    # Convert the input image to float
    input_image = input_image.astype(float)
    
    # Apply the selected transformation
    if transformation_type == 'gamma':
        # Gamma correction
        transformed_image = 255 * (input_image / 255) ** parameter
    elif transformation_type == 'log':
        # Logarithmic transformation
        transformed_image = parameter * np.log(1 + input_image)
    elif transformation_type == 'exp':
        # Exponential transformation
        transformed_image = np.exp(parameter * input_image)
    else:
        raise ValueError('Invalid transformation type. Use ''gamma'', ''log'', or ''exp''.')
    
    # Ensure the transformed image is in the valid intensity range [0, 255]
    transformed_image = np.clip(transformed_image, 0, 255)
    
    # Convert the transformed image to uint8 for display
    transformed_image = transformed_image.astype(np.uint8)
    
    # Display the original and transformed images
    plt.subplot(1, 2, 1), plt.imshow(cv2.cvtColor(input_image.astype(np.uint8), cv2.COLOR_BGR2RGB)), plt.title('Original Image')
    plt.subplot(1, 2, 2), plt.imshow(cv2.cvtColor(transformed_image, cv2.COLOR_BGR2RGB)), plt.title(f'Transformed Image - {transformation_type}')
    plt.show()

# %%
# Example usage:
# Load an example image
original_image = cv2.imread('image1.png')

# Display the original image
plt.subplot(1, 2, 1), plt.imshow(cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)), plt.title('Original Image')

# Example 1: Gamma Correction
gamma_value = 1.5
image_transformations(original_image, 'gamma', gamma_value)

# Example 2: Logarithmic Transformation
log_parameter = 0.1
image_transformations(original_image, 'log', log_parameter)

# Example 3: Exponential Transformation
exp_parameter = 0.005
image_transformations(original_image, 'exp', exp_parameter)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Leer la imagen desde un archivo
image = cv2.imread("image1.png")

# Verificar si la imagen se cargó correctamente
if image is None:
    print(f"Error: No se pudo cargar la imagen desde")
else:
    # Cambiar la intensidad del color (aumentar el brillo)
    intensity_factor = 1.5  # Puedes ajustar este valor según tus necesidades
    brightened_image = cv2.convertScaleAbs(image, alpha=intensity_factor, beta=0)

    # Ajustar el brillo y contraste (usando alpha y beta)
    alpha = 1.5  # Ajusta estos valores según tus necesidades
    beta = 30    # alpha controla el contraste, beta controla el brillo
    adjusted_image = cv2.addWeighted(image, alpha, np.zeros_like(image), 0, beta)

    # Mostrar las imágenes originales y transformadas
    plt.subplot(1, 3, 1), plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB)), plt.title('Imagen Original')
    plt.subplot(1, 3, 2), plt.imshow(cv2.cvtColor(brightened_image, cv2.COLOR_BGR2RGB)), plt.title('Intensidad del Color Aumentada')
    plt.subplot(1, 3, 3), plt.imshow(cv2.cvtColor(adjusted_image, cv2.COLOR_BGR2RGB)), plt.title('Brillo y Contraste Ajustados')
    plt.show()
